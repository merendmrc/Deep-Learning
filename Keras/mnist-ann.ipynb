# %% [markdown]
# **An artificial neural network model example with mnist dataset.**

# %% [markdown]
# Download dataset

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
import time

(train_img, train_lbl), (test_img, test_lbl) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# Preprossessing

# %%
from keras.utils import to_categorical
train_lbl = to_categorical(train_lbl)
test_lbl = to_categorical(test_lbl)

train_img = train_img.reshape((60000, 28 * 28))
train_img = train_img.astype('float32') / 255

test_img = test_img.reshape((10000, 28 * 28))
test_img = test_img.astype('float32') / 255

# %%
print(f"{train_img.shape},{test_img.shape}")
# Out:
# (60000, 784),(10000, 784)

# %% [markdown]
# Creating model

# %%
network = models.Sequential()

network.add(layers.Input(shape = (28 * 28,)))
network.add(layers.Dense(512, activation = "relu"))
network.add(layers.Dense(10, activation = "softmax"))

network.compile(optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %% [markdown]
# Train the model

# %%
network.fit(train_img, train_lbl, epochs = 100, batch_size = 128)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724668152.318155      80 service.cc:145] XLA service 0x7ba824006a80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724668152.318212      80 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  87/469 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7687 - loss: 0.8067
# I0000 00:00:1724668153.185933      80 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8777 - loss: 0.4304
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9660 - loss: 0.1184
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9780 - loss: 0.0726
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9851 - loss: 0.0507
# ...

# %%
loss, accuracy = network.evaluate(test_img, test_lbl)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9806 - loss: 0.0937

# %%
print(f"""
loss : {loss}
accuracy : {accuracy}

""")
# Out:
# loss : 0.07663732022047043
# accuracy : 0.9843999743461609
