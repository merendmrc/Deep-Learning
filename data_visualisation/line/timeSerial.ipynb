# %%
import seaborn as sns
import yfinance as yf
import pandas as pd

# %%
aapl = yf.download("AAPL", start ='2016-01-01', end ='2019-08-25')
df = aapl.copy()
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  23.886833  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.288235  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  22.832504  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  21.868868  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  21.984505  283192000
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-19  52.654999  53.182499  52.507500  52.587502  50.885979   97654400
# 2019-08-20  52.720001  53.337502  52.580002  52.590000  50.888397  107537200
# 2019-08-21  53.247501  53.412498  52.900002  53.160000  51.439957   86141600
# 2019-08-22  53.297501  53.610001  52.687500  53.115002  51.396423   89014800
# ...

# %%
close = df["Close"].reset_index(name="_close")
x = sns.lineplot(y="Low", x="Date", data= df)
sns.lineplot(y="High", x="Date", data= df)
# Out:
# <Axes: xlabel='Date', ylabel='Low'>

# %%
close.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)
