# %%
from matplotlib import pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()

# %%
# fig, ax = plt.subplots(1,2,figsize=(12,6))
sns.lmplot(x= "total_bill", y="tip", data=df, hue="smoker", row="time")
