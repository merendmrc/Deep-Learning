# %%
import seaborn as sns
from matplotlib import pyplot as plt
iris = sns.load_dataset("iris")
df = iris.copy()

# %%
x = sns.pairplot(df, hue="species", markers=["o","s","d"])

# %%
sns.kdeplot(x = "sepal_length", hue="species", shade= True ,data= df)
# Out:
# C:\Users\meren\AppData\Local\Temp\ipykernel_20016\2277996139.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = "sepal_length", hue="species", shade= True ,data= df)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
y = sns.pairplot(df, kind="reg", hue= "species")
