# %%
import seaborn as sbn
tips = sbn.load_dataset("tips")
df = tips.copy()

# %%
sbn.violinplot(x="sex", y="total_bill", data = df, hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ÇAPRAZLAMALAR
