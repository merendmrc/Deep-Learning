# %%
import seaborn as sbn
tips = sbn.load_dataset("tips")
df = tips.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
sbn.boxplot(x = df["total_bill"],color= "#C14953" , orient="y")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sbn.histplot(df.total_bill)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ÇAPRAZLAMA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
x= sbn.boxplot(x= df.day, y= df.total_bill, data=df)

# %% [markdown]
# Hangi gün daha fazla kazanılıyor

# %%
sbn.boxplot(x= "day", y="total_bill", data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# (sbn.FacetGrid(df, hue= "cut", height= 5, xlim= (0,10000))).map(sbn.kdeplot, "price", shade= True).add_legend()
x = sbn.FacetGrid(df, hue="time", height=5)
x.map(sbn.kdeplot, "total_bill", shade= True).add_legend()
x.set_axis_labels(x_var="eren", y_var="edm")
x.set_ylabels("demirci")
# Out:
# C:\Users\meren\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\meren\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
sbn.histplot(df.total_bill)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sbn.boxplot(x= "time", y="total_bill", data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sbn.boxplot(x= "size", y="total_bill", data=df, hue="sex")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>
